# %% [markdown]
# #Data Analysis on UNE HR sample data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv('Sheet 1-Table 1.csv')

# %%
df.head()
# Out:
#    EMPLOYEE#  SURNAME GENDER  FIRST_NAME Person Clevel Position Clevel  \
# 0     672021      NaN      M         NaN     1M02AA000       1M02AA000
# 1     672021      NaN      M         NaN     1N01AC000       1N01AC000
# 2     691916      NaN      F         NaN     1B14AD010       1B14AD010
# 3     691916      NaN      F         NaN     1K01AE000       1K01AE000
# 4     677056      NaN      F         NaN     1K03AA000       1K03AA000
#
#                Clevel3 Description  Clevel4 Description2  \
# 0                UNE International     UNE International
# 1  Information Technology Services  IT - Client Services
# 2     Faculty of Medicine & Health      School of Health
# 3            Teaching and Learning      Teaching Support
# 4               University Library    University Library
#
#          Clevel6 Description3                  TITLE CATEGORY CLASSIFICATION  \
# 0           UNE International  Casual Student Rate 1       GE          HEOS1
# ...

# %%
df['CATEGORY'].unique()
# Out:
# array(['GE', 'AC', 'EXEC', 'EXECA'], dtype=object)

# %%
df['EMP_STATUS'].unique()
# Out:
# array(['CA', 'PE', 'TE', 'CANL'], dtype=object)

# %%
cleaned_df = df.drop(['SURNAME', 'FIRST_NAME', 'Person Clevel', 'Position Clevel'], axis = 1)

# %%
# Out:
#    EMPLOYEE# GENDER              Clevel3 Description  Clevel4 Description2  \
# 0     672021      M                UNE International     UNE International
# 1     672021      M  Information Technology Services  IT - Client Services
# 2     691916      F     Faculty of Medicine & Health      School of Health
# 3     691916      F            Teaching and Learning      Teaching Support
# 4     677056      F               University Library    University Library
#
#          Clevel6 Description3                  TITLE CATEGORY CLASSIFICATION  \
# 0           UNE International  Casual Student Rate 1       GE          HEOS1
# 1        IT - Client Services  Casual Student Rate 2       GE          HEOS2
# 2  School of Health - Nursing    Casual General HEO1       GE           CAS1
# 3            Teaching Support   Casual General HEO 6       GE           CAS6
# 4          University Library    Casual General HEO3       GE           CAS3
#
# ...
